# %% [markdown]
# # CIFAR-10 Vision Objects — End-to-End Notebook
#
# A single, self-contained notebook for the AI-Engineering project **CIFAR Vision Objects**.
# Classify 32×32 RGB photos into one of 10 everyday object classes (airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck).
#
# This notebook is written for someone with **no prior Python or Machine-Learning experience**. Every step is
# explained in plain words next to the code that does it. You only need to run the cells from top to bottom.
#
# ## What this notebook does (in order)
#
# 1. **Setup** — install/import the libraries we need and configure the GPU.
# 2. **Clean own photos** — walk through `data/own/`, remove broken/too-small images, strip privacy metadata.
# 3. **Load data** — download CIFAR-10 (60 000 images, automatic) and load your own photos resized to 32×32.
# 4. **Explore the data** — class distribution, sample grids, channel statistics (rubric §2.2).
# 5. **Build two models** — a small CNN trained from scratch + MobileNetV2 transfer learning (rubric §3.2).
# 6. **Train experiments** — baseline, baseline + own photos, transfer learning.
# 7. **Hyperparameter tuning** — small grid search (rubric §3.4).
# 8. **Evaluate** — accuracy, per-class F1, confusion matrix, mispredictions on both CIFAR-test and your own photos (rubric §4).
# 9. **Explain** — Grad-CAM heatmaps showing where the model is looking (rubric §5.1).
# 10. **Predict a single image** — ready-to-use inference function.
# 11. **Summary + report tips**.
#
# ## How to use this notebook
#
# * Run cells **from top to bottom** the first time. After that you can re-run individual sections.
# * The first cell installs Python packages (uncomment the line if you have not already installed them).
# * Heavy training cells print their estimated runtime in a comment at the top. Skip experiments you don't need.
# * All outputs (plots, CSVs, model files) are saved into `models/` and `reports/` so you can paste them into the report.
# * The notebook works on CPU; if you have an NVIDIA GPU it is automatically used (much faster).
#
# > **Tip:** in JupyterLab use **Run ▸ Run All Cells** to execute the whole pipeline once. On CPU a full run is
# > ~1–2 hours; on a single A100 GPU it is ~10 minutes.

# %% [markdown]
# ## 0. Install dependencies (run once)
#
# Uncomment the `pip install` line below the first time you open the notebook. After it succeeds you can comment it back so subsequent runs are faster.

# %%
# Uncomment the next line on first run, then re-comment after install succeeds.
# %pip install tensorflow==2.20.0 keras==3.12.0 matplotlib==3.9.2 numpy==1.26.4 scikit-learn==1.5.2 pillow==10.4.0 pandas==2.2.3

# %% [markdown]
# ## 1. Imports + configuration
#
# * **NumPy** — fast number arrays; what TensorFlow uses under the hood.
# * **Pandas** — spreadsheet-like tables; we use it for results CSVs.
# * **Matplotlib** — plots (training curves, confusion matrix).
# * **PIL (Pillow)** — reads/writes image files (JPEG/PNG/...).
# * **TensorFlow / Keras** — the deep-learning library that builds and trains the neural network.
# * **scikit-learn** — evaluation metrics (precision, recall, F1, confusion matrix).
#
# The configuration block below is the only place you need to change settings (batch size, learning rate, paths).

# %%
import os, json, itertools
from pathlib import Path
from collections import Counter

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

import tensorflow as tf
from tensorflow.keras import layers, models, Input, mixed_precision
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import load_model, Model

from sklearn.metrics import (classification_report, confusion_matrix,
                             accuracy_score, precision_recall_fscore_support)

print('TensorFlow :', tf.__version__)
print('Keras      :', tf.keras.__version__)
# Out:
# TensorFlow : 2.20.0
# Keras      : 3.12.0

# %%
# ---------------------------------------------------------------------------
# Paths (auto-relative to the notebook location — no edits needed when you
# move the project folder).
# ---------------------------------------------------------------------------
ROOT        = Path.cwd()
DATA_DIR    = ROOT / 'data'
OWN_DIR     = DATA_DIR / 'own'
MODELS_DIR  = ROOT / 'models'
REPORTS_DIR = ROOT / 'reports'
FIGURES_DIR = REPORTS_DIR / 'figures'
TABLES_DIR  = REPORTS_DIR / 'tables'
for d in (DATA_DIR, OWN_DIR, MODELS_DIR, REPORTS_DIR, FIGURES_DIR, TABLES_DIR):
    d.mkdir(parents=True, exist_ok=True)

# ---------------------------------------------------------------------------
# Dataset constants (do NOT change — CIFAR-10 is fixed at 10 classes / 32x32)
# ---------------------------------------------------------------------------
IMG_SIZE     = 32
NUM_CLASSES  = 10
CHANNELS     = 3
CLASS_NAMES  = ['airplane', 'automobile', 'bird', 'cat', 'deer',
                'dog', 'frog', 'horse', 'ship', 'truck']
SUPPORTED_EXT = {'.jpg', '.jpeg', '.png', '.bmp', '.webp'}

# ---------------------------------------------------------------------------
# Training hyperparameters (you may edit these)
# ---------------------------------------------------------------------------
SEED                    = 42      # makes runs reproducible
BATCH_SIZE              = 64      # lower this to 32 if you get out-of-memory errors
EPOCHS                  = 50      # max epochs; EarlyStopping will stop sooner
LEARNING_RATE           = 1e-3
EARLY_STOPPING_PATIENCE = 8
VALIDATION_SPLIT_SIZE   = 5000    # how many CIFAR-train images we hold out for validation

# Quick-mode: shrink epoch counts so you can do a fast end-to-end smoke test.
# Set QUICK_MODE = False for the real training run that goes into your report.
QUICK_MODE = False
if QUICK_MODE:
    EPOCHS = 3
    print('QUICK_MODE on — epochs reduced to', EPOCHS)

# Reproducibility seeds
np.random.seed(SEED)
tf.random.set_seed(SEED)

print('ROOT        =', ROOT)
print('OWN_DIR     =', OWN_DIR)
print('MODELS_DIR  =', MODELS_DIR)
print('REPORTS_DIR =', REPORTS_DIR)
# Out:
# ROOT        = C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project
# OWN_DIR     = C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\data\own
# MODELS_DIR  = C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models
# REPORTS_DIR = C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports

# %%
# ---------------------------------------------------------------------------
# GPU setup (safe on CPU-only laptops too)
# ---------------------------------------------------------------------------
# Two settings, both recommended by the AI-server guide:
#  1. memory growth = ON  -> only take the GPU memory we actually need
#                            so other course groups can share the server.
#  2. mixed_float16       -> ~2x faster training on modern GPUs (A100, RTX);
#                            silently no-op on CPU.
USE_MIXED_PRECISION = True

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f'Found {len(gpus)} GPU(s):')
    for i, g in enumerate(gpus):
        print(f'  [{i}] {g.name}')
    try:
        for g in gpus:
            tf.config.experimental.set_memory_growth(g, True)
        print('GPU memory growth: ON')
    except RuntimeError as e:
        print('Could not enable memory growth:', e)
    if USE_MIXED_PRECISION:
        mixed_precision.set_global_policy('mixed_float16')
        print('Mixed precision policy:', mixed_precision.global_policy().name)
else:
    print('No GPU detected. Training will run on CPU (slower but works).')
# Out:
# No GPU detected. Training will run on CPU (slower but works).

# %% [markdown]
# ## 2. Validate and clean your own photos
#
# `data/own/` has one folder per class (`0_airplane/`, `1_automobile/`, ...). The next cell:
#
# * skips files that are not images (`.json`, `.pickle`, hidden files, etc.);
# * opens every image to verify it is not corrupted;
# * removes images smaller than 32×32 (they would have to be upscaled, which is misleading);
# * optionally **strips EXIF metadata** (GPS, camera serial number) for privacy;
# * optionally **deletes** the bad files in place.
#
# The first run is a *dry run* (it just lists what would be removed). The second cell does the actual removal.

# %%
def clean_own_folder(delete_bad: bool = False, strip_exif: bool = False, min_side: int = 32):
    """Walk data/own/ and validate every image. Returns a summary DataFrame."""
    rows = []
    for ci, name in enumerate(CLASS_NAMES):
        folder = OWN_DIR / f'{ci}_{name}'
        if not folder.exists():
            rows.append((name, 0, 0, 0))
            continue
        kept = removed = non_image = 0
        for f in sorted(folder.iterdir()):
            if not f.is_file():
                continue
            if f.suffix.lower() not in SUPPORTED_EXT:
                non_image += 1
                continue
            try:
                # 1. integrity check
                with Image.open(f) as im:
                    im.verify()
                # 2. size check (re-open since verify() consumes the file)
                with Image.open(f) as im:
                    w, h = im.size
                    if min(w, h) < min_side:
                        raise ValueError(f'too small: {w}x{h}')
                    if strip_exif and f.suffix.lower() in {'.jpg', '.jpeg'}:
                        clean = Image.new('RGB', im.size)
                        clean.putdata(list(im.convert('RGB').getdata()))
                        clean.save(f, 'JPEG', quality=92)
                kept += 1
            except Exception as e:
                if delete_bad:
                    f.unlink(missing_ok=True)
                    removed += 1
                else:
                    print(f'  [BAD]  {f.relative_to(OWN_DIR)} -> {e}')
                    removed += 1
        rows.append((name, kept, removed, non_image))
    return pd.DataFrame(rows, columns=['class', 'kept', 'bad', 'non-image-files'])

print('Dry run — nothing has been deleted yet.')
print('Files marked [BAD] will be deleted only if you set delete_bad=True in the next cell.\n')
clean_own_folder(delete_bad=False, strip_exif=False)
# Out:
# Dry run — nothing has been deleted yet.
# Files marked [BAD] will be deleted only if you set delete_bad=True in the next cell.
#         class  kept  bad  non-image-files
# 0    airplane    37    0                0
# 1  automobile    55    0                0
# 2        bird    68    0                1
# 3         cat    78    0                2
# 4        deer    68    0                1
# 5         dog    53    0                1
# 6        frog    78    0                1
# 7       horse    55    0                1
# 8        ship    26    0                1
# 9       truck    29    0                1

# %%
# Real cleanup pass.  Comment this cell out (or change delete_bad=False) if you
# want to keep every file untouched.
result = clean_own_folder(delete_bad=True, strip_exif=True, min_side=32)
print(result)
print('\nTotal photos kept :', int(result['kept'].sum()))
print('Total deleted     :', int(result['bad'].sum()))
print('Non-image files   :', int(result['non-image-files'].sum()), '(ignored, not deleted)')
# Out:
#         class  kept  bad  non-image-files
# 0    airplane    37    0                0
# 1  automobile    55    0                0
# 2        bird    68    0                1
# 3         cat    78    0                2
# 4        deer    68    0                1
# 5         dog    53    0                1
# 6        frog    78    0                1
# 7       horse    55    0                1
# 8        ship    26    0                1
# 9       truck    29    0                1
#
# Total photos kept : 547
# Total deleted     : 0
# Non-image files   : 9 (ignored, not deleted)

# %% [markdown]
# ## 3. Load CIFAR-10 and your own photos
#
# * **CIFAR-10** is downloaded automatically the first time (~170 MB, then cached in `~/.keras/`).
# * We split the 50 000 training images into **45 000 train + 5 000 validation** with a fixed seed.
#   The 10 000 test images are *never* used during training (rubric §2.5).
# * **Own photos** are resized from their original size to 32×32 to match CIFAR (rubric requires preprocessing be reproducible — §2.4).

# %%
def load_cifar10():
    (x_full, y_full), (x_test, y_test) = cifar10.load_data()
    y_full = y_full.flatten()
    y_test = y_test.flatten()
    rng = np.random.default_rng(SEED)
    idx = rng.permutation(len(x_full))
    x_full, y_full = x_full[idx], y_full[idx]
    x_val,   y_val   = x_full[:VALIDATION_SPLIT_SIZE], y_full[:VALIDATION_SPLIT_SIZE]
    x_train, y_train = x_full[VALIDATION_SPLIT_SIZE:], y_full[VALIDATION_SPLIT_SIZE:]
    print(f'CIFAR-10 -> train={len(x_train)}  val={len(x_val)}  test={len(x_test)}')
    return (x_train, y_train), (x_val, y_val), (x_test, y_test)

(x_train, y_train), (x_val, y_val), (x_test, y_test) = load_cifar10()
print('shape sanity check:', x_train.shape, x_train.dtype, '| pixel range', x_train.min(), '..', x_train.max())
# Out:
# CIFAR-10 -> train=45000  val=5000  test=10000
# shape sanity check: (45000, 32, 32, 3) uint8 | pixel range 0 .. 255

# %%
def load_own_images():
    Xs, ys, skipped = [], [], 0
    for ci, name in enumerate(CLASS_NAMES):
        folder = OWN_DIR / f'{ci}_{name}'
        if not folder.exists():
            continue
        for f in sorted(folder.iterdir()):
            if f.suffix.lower() not in SUPPORTED_EXT:
                continue
            try:
                img = Image.open(f).convert('RGB').resize((IMG_SIZE, IMG_SIZE))
                Xs.append(np.asarray(img, dtype=np.uint8))
                ys.append(ci)
            except Exception as e:
                print(f'  skip {f.name}: {e}')
                skipped += 1
    if not Xs:
        return (np.empty((0, IMG_SIZE, IMG_SIZE, 3), dtype=np.uint8),
                np.empty((0,), dtype=np.int64))
    X = np.stack(Xs)
    y = np.array(ys, dtype=np.int64)
    print(f'Own images: {len(X)} loaded ({skipped} skipped)')
    for ci in range(NUM_CLASSES):
        print(f'  {ci}_{CLASS_NAMES[ci]:10s}: {(y == ci).sum():3d} images')
    return X, y

X_own, y_own = load_own_images()
# Out:
# Own images: 547 loaded (0 skipped)
#   0_airplane  :  37 images
#   1_automobile:  55 images
#   2_bird      :  68 images
#   3_cat       :  78 images
#   4_deer      :  68 images
#   5_dog       :  53 images
#   6_frog      :  78 images
#   7_horse     :  55 images
#   8_ship      :  26 images
#   9_truck     :  29 images

# %%
def split_own(X, y, train_fraction=0.6):
    """60/40 shuffle of own images: 60% added to training, 40% kept as own-test."""
    if len(X) == 0:
        empty = (np.empty((0,) + X.shape[1:], dtype=X.dtype),
                 np.empty((0,), dtype=y.dtype))
        return empty, empty
    rng = np.random.default_rng(SEED)
    idx = rng.permutation(len(X))
    cut = int(len(X) * train_fraction)
    return (X[idx[:cut]], y[idx[:cut]]), (X[idx[cut:]], y[idx[cut:]])

def build_splits(include_own_in_training: bool):
    """Return train/val/test_cifar/test_own arrays for a chosen experiment."""
    if include_own_in_training and len(X_own) > 0:
        (xo_tr, yo_tr), (xo_te, yo_te) = split_own(X_own, y_own)
        x_tr = np.concatenate([x_train, xo_tr], axis=0)
        y_tr = np.concatenate([y_train, yo_tr], axis=0)
        print(f'Added {len(xo_tr)} own images to training (new size {len(x_tr)})')
    else:
        x_tr, y_tr = x_train, y_train
        xo_te, yo_te = X_own, y_own
    return {
        'train':      (x_tr,  y_tr),
        'val':        (x_val, y_val),
        'test_cifar': (x_test, y_test),
        'test_own':   (xo_te, yo_te),
    }

# %% [markdown]
# ## 4. Exploratory Data Analysis (rubric §2.2)
#
# Before training any model we look at the dataset to spot problems (class imbalance, weird pixel values, etc.).
# All plots below are saved into `reports/figures/` so you can paste them into the report.

# %%
df_dist = pd.DataFrame({
    'class':       CLASS_NAMES,
    'cifar_train': [int((y_train == i).sum()) for i in range(10)],
    'cifar_test':  [int((y_test  == i).sum()) for i in range(10)],
    'own':         [int((y_own   == i).sum()) for i in range(10)] if len(y_own) else [0] * 10,
})
df_dist.to_csv(TABLES_DIR / 'eda_class_distribution.csv', index=False)
df_dist
# Out:
#         class  cifar_train  cifar_test  own
# 0    airplane         4527        1000   37
# 1  automobile         4458        1000   55
# 2        bird         4465        1000   68
# 3         cat         4518        1000   78
# 4        deer         4477        1000   68
# 5         dog         4527        1000   53
# 6        frog         4498        1000   78
# 7       horse         4531        1000   55
# 8        ship         4482        1000   26
# 9       truck         4517        1000   29

# %%
fig, ax = plt.subplots(figsize=(11, 4))
x = np.arange(len(CLASS_NAMES))
w = 0.27
ax.bar(x - w, df_dist['cifar_train'], w, label='CIFAR train')
ax.bar(x,     df_dist['cifar_test'],  w, label='CIFAR test')
ax.bar(x + w, df_dist['own'],         w, label='Own')
ax.set_xticks(x); ax.set_xticklabels(CLASS_NAMES, rotation=30, ha='right')
ax.set_ylabel('# images'); ax.set_title('Class distribution')
ax.legend(); ax.grid(axis='y', alpha=0.3)
fig.tight_layout()
out = FIGURES_DIR / 'eda_class_distribution.png'
fig.savefig(out, dpi=150); plt.show()
print('saved', out)
# Out:
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\eda_class_distribution.png

# %%
rng = np.random.default_rng(0)
fig, axes = plt.subplots(10, 10, figsize=(12, 12))
for ci, name in enumerate(CLASS_NAMES):
    pool = np.where(y_train == ci)[0]
    picks = rng.choice(pool, size=10, replace=False)
    for j, idx in enumerate(picks):
        ax = axes[ci, j]
        ax.imshow(x_train[idx]); ax.axis('off')
        if j == 0:
            ax.set_ylabel(name, rotation=0, labelpad=40, fontsize=10, ha='right', va='center')
fig.suptitle('CIFAR-10: 10 random samples per class')
fig.tight_layout()
out = FIGURES_DIR / 'eda_cifar_samples.png'
fig.savefig(out, dpi=150); plt.show()
print('saved', out)
# Out:
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\eda_cifar_samples.png

# %%
means = x_train.astype(np.float32).mean(axis=(0, 1, 2))
stds  = x_train.astype(np.float32).std(axis=(0, 1, 2))
print(f'Channel means (R, G, B): {means.round(1).tolist()}')
print(f'Channel stds  (R, G, B): {stds.round(1).tolist()}')

if len(X_own) > 0:
    n = min(40, len(X_own))
    cols = 8
    rows = int(np.ceil(n / cols))
    fig, axes = plt.subplots(rows, cols, figsize=(12, 1.8 * rows))
    axes = axes.flatten()
    rng2 = np.random.default_rng(1)
    show_idx = rng2.choice(len(X_own), size=n, replace=False)
    for i, ax in enumerate(axes):
        if i >= n:
            ax.axis('off'); continue
        idx = show_idx[i]
        ax.imshow(X_own[idx]); ax.set_title(CLASS_NAMES[y_own[idx]], fontsize=8); ax.axis('off')
    fig.suptitle('Own images (resized to 32x32)')
    fig.tight_layout()
    out = FIGURES_DIR / 'eda_own_samples.png'
    fig.savefig(out, dpi=150); plt.show()
    print('saved', out)
else:
    print('No own images available — add some to data/own/ and re-run.')
# Out:
# Channel means (R, G, B): [125.19999694824219, 122.9000015258789, 113.9000015258789]
# Channel stds  (R, G, B): [63.0, 62.099998474121094, 66.69999694824219]
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\eda_own_samples.png

# %% [markdown]
# ## 5. Model architectures (rubric §3.1, §3.2)
#
# We build two **substantively different** models so we can compare them later:
#
# ### Model A — baseline CNN trained from scratch
# A small 3-block convolutional network (~158 k parameters). Reaches ~80% accuracy on CIFAR-10.
#
# ### Model B — MobileNetV2 transfer learning (pre-trained on ImageNet)
# MobileNetV2 was trained on 1.4 M ImageNet photos and already understands generic object features. We **freeze**
# its weights and train only a small classifier head on top. Usually beats the baseline.
#
# Both models accept raw `uint8` images in 0..255 and normalise inside the model so the calling code stays simple.

# %%
def _augmentation_block():
    """Random transforms applied during TRAINING only — reduces overfitting.
    No vertical flip (an upside-down airplane is a wrong training signal)."""
    return tf.keras.Sequential([
        layers.RandomFlip('horizontal'),
        layers.RandomRotation(0.08),
        layers.RandomZoom(0.10),
        layers.RandomTranslation(0.10, 0.10),
    ], name='augmentation')

def build_baseline_cnn(learning_rate: float = LEARNING_RATE, dropout: float = 0.5):
    inputs = Input(shape=(IMG_SIZE, IMG_SIZE, CHANNELS))
    x = _augmentation_block()(inputs)
    x = layers.Rescaling(1.0 / 255.0)(x)

    # Block 1: 32 filters
    x = layers.Conv2D(32, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(32, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D()(x)
    x = layers.Dropout(dropout / 2)(x)

    # Block 2: 64 filters
    x = layers.Conv2D(64, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(64, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D()(x)
    x = layers.Dropout(dropout / 2)(x)

    # Block 3: 128 filters + global pooling
    x = layers.Conv2D(128, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.GlobalAveragePooling2D()(x)

    # Head
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(dropout)(x)
    outputs = layers.Dense(NUM_CLASSES, activation='softmax', dtype='float32', name='predictions')(x)

    model = models.Model(inputs, outputs, name='baseline_cnn')
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy'],
    )
    return model

def build_transfer_model(learning_rate: float = LEARNING_RATE, fine_tune: bool = False):
    inputs = Input(shape=(IMG_SIZE, IMG_SIZE, CHANNELS))
    x = _augmentation_block()(inputs)
    x = layers.Resizing(96, 96)(x)
    x = layers.Rescaling(scale=1.0 / 127.5, offset=-1.0, name='mobilenet_preprocess')(x)
    backbone = MobileNetV2(input_shape=(96, 96, 3),
                           include_top=False, weights='imagenet',
                           pooling='avg')
    backbone.trainable = fine_tune
    x = backbone(x, training=fine_tune)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(NUM_CLASSES, activation='softmax', dtype='float32', name='predictions')(x)

    model = models.Model(inputs, outputs, name='mobilenetv2_transfer')
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy'],
    )
    return model

print('--- baseline_cnn ---')
build_baseline_cnn().summary()
print('\n--- mobilenetv2_transfer ---')
build_transfer_model().summary()
# Out:
# --- baseline_cnn ---
# Model: "baseline_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ augmentation (Sequential)            │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling (Rescaling)                │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 32, 32, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 32, 32, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 16, 16, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 16, 16, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 128)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ predictions (Dense)                  │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 158,506 (619.16 KB)
#  Trainable params: 157,866 (616.66 KB)
#  Non-trainable params: 640 (2.50 KB)
# --- mobilenetv2_transfer ---
# Model: "mobilenetv2_transfer"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ augmentation (Sequential)            │ (None, 32, 32, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ resizing (Resizing)                  │ (None, 96, 96, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ mobilenet_preprocess (Rescaling)     │ (None, 96, 96, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ mobilenetv2_1.00_96 (Functional)     │ (None, 1280)                │       2,257,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 1280)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ predictions (Dense)                  │ (None, 10)                  │          12,810 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,270,794 (8.66 MB)
#  Trainable params: 12,810 (50.04 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# ## 6. Training utilities
#
# The `train_model` function below trains any model with the same callbacks so the comparison is fair (rubric §3.5).
#
# * **EarlyStopping** — stop training when the validation accuracy stops improving for `EARLY_STOPPING_PATIENCE` epochs.
# * **ModelCheckpoint** — always save the *best* model seen so far to `models/<run_name>.keras`.
# * **ReduceLROnPlateau** — halve the learning rate if validation loss plateaus.
# * **CSVLogger** — record per-epoch metrics to `reports/tables/history_<run_name>.csv`.
#
# The function also saves a JSON config (rubric §3.6 reproducibility) and a PNG with loss & accuracy curves (rubric §4.7 overfitting analysis).

# %%
def plot_curves(history, run_name: str):
    h = history.history
    epochs = range(1, len(h['loss']) + 1)
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    axes[0].plot(epochs, h['loss'], label='train')
    axes[0].plot(epochs, h['val_loss'], label='val')
    axes[0].set_xlabel('Epoch'); axes[0].set_ylabel('Loss')
    axes[0].set_title(f'Loss — {run_name}'); axes[0].legend(); axes[0].grid(True, alpha=0.3)
    axes[1].plot(epochs, h['accuracy'], label='train')
    axes[1].plot(epochs, h['val_accuracy'], label='val')
    axes[1].set_xlabel('Epoch'); axes[1].set_ylabel('Accuracy')
    axes[1].set_title(f'Accuracy — {run_name}'); axes[1].legend(); axes[1].grid(True, alpha=0.3)
    out = FIGURES_DIR / f'curves_{run_name}.png'
    fig.tight_layout(); fig.savefig(out, dpi=150); plt.show()
    print('saved', out)

def train_model(model, run_name: str, splits, epochs=None, batch_size=BATCH_SIZE):
    if epochs is None:
        epochs = EPOCHS
    x_tr, y_tr = splits['train']
    x_va, y_va = splits['val']
    model_path = MODELS_DIR / f'{run_name}.keras'
    log_path   = TABLES_DIR / f'history_{run_name}.csv'
    callbacks = [
        EarlyStopping(monitor='val_accuracy', patience=EARLY_STOPPING_PATIENCE,
                      restore_best_weights=True, verbose=1),
        ModelCheckpoint(filepath=str(model_path), monitor='val_accuracy',
                        save_best_only=True, verbose=1),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4,
                          min_lr=1e-6, verbose=1),
        CSVLogger(str(log_path), append=False),
    ]
    history = model.fit(
        x_tr, y_tr, validation_data=(x_va, y_va),
        batch_size=batch_size, epochs=epochs, callbacks=callbacks, verbose=2)
    cfg = {
        'run_name': run_name,
        'model_name': model.name,
        'epochs_max': epochs,
        'epochs_run': len(history.history['loss']),
        'batch_size': batch_size,
        'best_val_accuracy': float(max(history.history['val_accuracy'])),
        'training_size': int(len(x_tr)),
        'validation_size': int(len(x_va)),
    }
    with open(TABLES_DIR / f'config_{run_name}.json', 'w') as fp:
        json.dump(cfg, fp, indent=2)
    plot_curves(history, run_name)
    print(f"\n[{run_name}] best val_accuracy = {cfg['best_val_accuracy']:.4f}, saved to {model_path}")
    return history

# %% [markdown]
# ## 7. Run the experiments
#
# Three main experiments. Run them one at a time. **Estimated time per run on a single A100 GPU: 3–8 min;
# on a CPU laptop: 30–90 min.** If you only have time for one, run **Experiment 1** — it gives you all the
# rubric-required artifacts for the baseline model.

# %%
# Experiment 1 — baseline CNN, CIFAR-10 only
splits_cifar = build_splits(include_own_in_training=False)
model_baseline = build_baseline_cnn()
hist_baseline = train_model(model_baseline, run_name='exp1_baseline', splits=splits_cifar)
# Out:
# Epoch 1/50
#
# Epoch 1: val_accuracy improved from None to 0.38720, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp1_baseline.keras
# 704/704 - 102s - 144ms/step - accuracy: 0.3961 - loss: 1.6590 - val_accuracy: 0.3872 - val_loss: 1.8840 - learning_rate: 0.0010
# Epoch 2/50
#
# Epoch 2: val_accuracy improved from 0.38720 to 0.43560, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp1_baseline.keras
# 704/704 - 97s - 138ms/step - accuracy: 0.5215 - loss: 1.3458 - val_accuracy: 0.4356 - val_loss: 1.7710 - learning_rate: 0.0010
# Epoch 3/50
#
# Epoch 3: val_accuracy improved from 0.43560 to 0.49380, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp1_baseline.keras
# 704/704 - 94s - 134ms/step - accuracy: 0.5695 - loss: 1.2165 - val_accuracy: 0.4938 - val_loss: 1.5851 - learning_rate: 0.0010
# Epoch 4/50
#
# Epoch 4: val_accuracy did not improve from 0.49380
# 704/704 - 99s - 140ms/step - accuracy: 0.6000 - loss: 1.1351 - val_accuracy: 0.4752 - val_loss: 1.7094 - learning_rate: 0.0010
# Epoch 5/50
#
# Epoch 5: val_accuracy improved from 0.49380 to 0.53800, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp1_baseline.keras
# 704/704 - 97s - 138ms/step - accuracy: 0.6290 - loss: 1.0612 - val_accuracy: 0.5380 - val_loss: 1.4746 - learning_rate: 0.0010
# Epoch 6/50
#
# Epoch 6: val_accuracy improved from 0.53800 to 0.58380, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp1_baseline.keras
# 704/704 - 103s - 147ms/step - accuracy: 0.6497 - loss: 1.0133 - val_accuracy: 0.5838 - val_loss: 1.2692 - learning_rate: 0.0010
# Epoch 7/50
#
# Epoch 7: val_accuracy improved from 0.58380 to 0.65840, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp1_baseline.keras
# 704/704 - 142s - 201ms/step - accuracy: 0.6651 - loss: 0.9658 - val_accuracy: 0.6584 - val_loss: 0.9951 - learning_rate: 0.0010
# Epoch 8/50
#
# Epoch 8: val_accuracy did not improve from 0.65840
# 704/704 - 144s - 204ms/step - accuracy: 0.6811 - loss: 0.9294 - val_accuracy: 0.5558 - val_loss: 1.4070 - learning_rate: 0.0010
# Epoch 9/50
#
# Epoch 9: val_accuracy did not improve from 0.65840
# 704/704 - 98s - 139ms/step - accuracy: 0.6908 - loss: 0.8997 - val_accuracy: 0.6060 - val_loss: 1.2359 - learning_rate: 0.0010
# Epoch 10/50
#
# Epoch 10: val_accuracy improved from 0.65840 to 0.71360, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp1_baseline.keras
# 704/704 - 97s - 138ms/step - accuracy: 0.7002 - loss: 0.8732 - val_accuracy: 0.7136 - val_loss: 0.8731 - learning_rate: 0.0010
# Epoch 11/50
#
# Epoch 11: val_accuracy did not improve from 0.71360
# 704/704 - 96s - 137ms/step - accuracy: 0.7091 - loss: 0.8529 - val_accuracy: 0.6676 - val_loss: 1.0259 - learning_rate: 0.0010
# Epoch 12/50
#
# Epoch 12: val_accuracy did not improve from 0.71360
# 704/704 - 89s - 126ms/step - accuracy: 0.7157 - loss: 0.8323 - val_accuracy: 0.6412 - val_loss: 1.1863 - learning_rate: 0.0010
# Epoch 13/50
#
# Epoch 13: val_accuracy did not improve from 0.71360
# 704/704 - 91s - 129ms/step - accuracy: 0.7210 - loss: 0.8150 - val_accuracy: 0.6960 - val_loss: 0.9124 - learning_rate: 0.0010
# Epoch 14/50
#
# Epoch 14: val_accuracy improved from 0.71360 to 0.71940, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp1_baseline.keras
# 704/704 - 143s - 204ms/step - accuracy: 0.7260 - loss: 0.8006 - val_accuracy: 0.7194 - val_loss: 0.8587 - learning_rate: 0.0010
# Epoch 15/50
#
# Epoch 15: val_accuracy did not improve from 0.71940
# 704/704 - 82s - 116ms/step - accuracy: 0.7308 - loss: 0.7898 - val_accuracy: 0.6996 - val_loss: 1.0069 - learning_rate: 0.0010
# Epoch 16/50
#
# Epoch 16: val_accuracy did not improve from 0.71940
# 704/704 - 84s - 119ms/step - accuracy: 0.7347 - loss: 0.7748 - val_accuracy: 0.6920 - val_loss: 0.9707 - learning_rate: 0.0010
# Epoch 17/50
#
# Epoch 17: val_accuracy did not improve from 0.71940
# 704/704 - 86s - 122ms/step - accuracy: 0.7386 - loss: 0.7669 - val_accuracy: 0.6964 - val_loss: 0.9431 - learning_rate: 0.0010
# Epoch 18/50
#
# Epoch 18: val_accuracy did not improve from 0.71940
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 704/704 - 89s - 127ms/step - accuracy: 0.7450 - loss: 0.7493 - val_accuracy: 0.7166 - val_loss: 0.9406 - learning_rate: 0.0010
# Epoch 19/50
#
# Epoch 19: val_accuracy improved from 0.71940 to 0.71980, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp1_baseline.keras
# 704/704 - 92s - 131ms/step - accuracy: 0.7580 - loss: 0.7074 - val_accuracy: 0.7198 - val_loss: 0.8511 - learning_rate: 5.0000e-04
# Epoch 20/50
#
# Epoch 20: val_accuracy improved from 0.71980 to 0.72020, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp1_baseline.keras
# 704/704 - 97s - 137ms/step - accuracy: 0.7600 - loss: 0.6994 - val_accuracy: 0.7202 - val_loss: 0.8723 - learning_rate: 5.0000e-04
# Epoch 21/50
#
# Epoch 21: val_accuracy improved from 0.72020 to 0.75520, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp1_baseline.keras
# 704/704 - 91s - 130ms/step - accuracy: 0.7651 - loss: 0.6905 - val_accuracy: 0.7552 - val_loss: 0.7438 - learning_rate: 5.0000e-04
# Epoch 22/50
#
# Epoch 22: val_accuracy did not improve from 0.75520
# 704/704 - 94s - 134ms/step - accuracy: 0.7675 - loss: 0.6803 - val_accuracy: 0.7530 - val_loss: 0.7638 - learning_rate: 5.0000e-04
# Epoch 23/50
#
# Epoch 23: val_accuracy did not improve from 0.75520
# 704/704 - 98s - 139ms/step - accuracy: 0.7684 - loss: 0.6753 - val_accuracy: 0.7462 - val_loss: 0.7452 - learning_rate: 5.0000e-04
# Epoch 24/50
#
# Epoch 24: val_accuracy did not improve from 0.75520
# 704/704 - 96s - 136ms/step - accuracy: 0.7723 - loss: 0.6696 - val_accuracy: 0.7338 - val_loss: 0.8181 - learning_rate: 5.0000e-04
# Epoch 25/50
#
# Epoch 25: val_accuracy did not improve from 0.75520
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 704/704 - 105s - 149ms/step - accuracy: 0.7719 - loss: 0.6636 - val_accuracy: 0.7544 - val_loss: 0.7956 - learning_rate: 5.0000e-04
# Epoch 26/50
#
# Epoch 26: val_accuracy improved from 0.75520 to 0.76360, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp1_baseline.keras
# 704/704 - 113s - 161ms/step - accuracy: 0.7820 - loss: 0.6454 - val_accuracy: 0.7636 - val_loss: 0.7234 - learning_rate: 2.5000e-04
# Epoch 27/50
#
# Epoch 27: val_accuracy did not improve from 0.76360
# 704/704 - 105s - 150ms/step - accuracy: 0.7835 - loss: 0.6390 - val_accuracy: 0.7604 - val_loss: 0.7418 - learning_rate: 2.5000e-04
# Epoch 28/50
#
# Epoch 28: val_accuracy improved from 0.76360 to 0.77680, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp1_baseline.keras
# 704/704 - 107s - 153ms/step - accuracy: 0.7846 - loss: 0.6324 - val_accuracy: 0.7768 - val_loss: 0.6774 - learning_rate: 2.5000e-04
# Epoch 29/50
#
# Epoch 29: val_accuracy did not improve from 0.77680
# 704/704 - 100s - 141ms/step - accuracy: 0.7848 - loss: 0.6309 - val_accuracy: 0.7508 - val_loss: 0.7453 - learning_rate: 2.5000e-04
# Epoch 30/50
#
# Epoch 30: val_accuracy did not improve from 0.77680
# 704/704 - 112s - 159ms/step - accuracy: 0.7857 - loss: 0.6285 - val_accuracy: 0.7748 - val_loss: 0.7005 - learning_rate: 2.5000e-04
# Epoch 31/50
#
# Epoch 31: val_accuracy did not improve from 0.77680
# 704/704 - 123s - 175ms/step - accuracy: 0.7885 - loss: 0.6219 - val_accuracy: 0.7754 - val_loss: 0.6782 - learning_rate: 2.5000e-04
# Epoch 32/50
#
# Epoch 32: val_accuracy improved from 0.77680 to 0.78660, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp1_baseline.keras
# 704/704 - 109s - 154ms/step - accuracy: 0.7872 - loss: 0.6258 - val_accuracy: 0.7866 - val_loss: 0.6384 - learning_rate: 2.5000e-04
# Epoch 33/50
#
# Epoch 33: val_accuracy did not improve from 0.78660
# 704/704 - 98s - 138ms/step - accuracy: 0.7892 - loss: 0.6196 - val_accuracy: 0.7840 - val_loss: 0.6550 - learning_rate: 2.5000e-04
# Epoch 34/50
#
# Epoch 34: val_accuracy did not improve from 0.78660
# 704/704 - 104s - 148ms/step - accuracy: 0.7876 - loss: 0.6199 - val_accuracy: 0.7644 - val_loss: 0.7319 - learning_rate: 2.5000e-04
# Epoch 35/50
#
# Epoch 35: val_accuracy did not improve from 0.78660
# 704/704 - 103s - 146ms/step - accuracy: 0.7910 - loss: 0.6128 - val_accuracy: 0.7812 - val_loss: 0.6550 - learning_rate: 2.5000e-04
# Epoch 36/50
#
# Epoch 36: val_accuracy did not improve from 0.78660
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 704/704 - 111s - 158ms/step - accuracy: 0.7927 - loss: 0.6097 - val_accuracy: 0.7784 - val_loss: 0.6823 - learning_rate: 2.5000e-04
# Epoch 37/50
#
# Epoch 37: val_accuracy did not improve from 0.78660
# 704/704 - 98s - 139ms/step - accuracy: 0.7979 - loss: 0.5950 - val_accuracy: 0.7840 - val_loss: 0.6629 - learning_rate: 1.2500e-04
# Epoch 38/50
#
# Epoch 38: val_accuracy improved from 0.78660 to 0.78860, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp1_baseline.keras
# 704/704 - 99s - 140ms/step - accuracy: 0.7930 - loss: 0.6032 - val_accuracy: 0.7886 - val_loss: 0.6339 - learning_rate: 1.2500e-04
# Epoch 39/50
#
# Epoch 39: val_accuracy did not improve from 0.78860
# 704/704 - 100s - 142ms/step - accuracy: 0.7964 - loss: 0.5980 - val_accuracy: 0.7870 - val_loss: 0.6539 - learning_rate: 1.2500e-04
# Epoch 40/50
#
# Epoch 40: val_accuracy improved from 0.78860 to 0.79000, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp1_baseline.keras
# 704/704 - 101s - 143ms/step - accuracy: 0.7996 - loss: 0.5913 - val_accuracy: 0.7900 - val_loss: 0.6374 - learning_rate: 1.2500e-04
# Epoch 41/50
#
# Epoch 41: val_accuracy did not improve from 0.79000
# 704/704 - 97s - 137ms/step - accuracy: 0.8003 - loss: 0.5899 - val_accuracy: 0.7890 - val_loss: 0.6515 - learning_rate: 1.2500e-04
# Epoch 42/50
#
# Epoch 42: val_accuracy did not improve from 0.79000
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 704/704 - 97s - 137ms/step - accuracy: 0.7977 - loss: 0.5912 - val_accuracy: 0.7890 - val_loss: 0.6492 - learning_rate: 1.2500e-04
# Epoch 43/50
#
# Epoch 43: val_accuracy improved from 0.79000 to 0.79220, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp1_baseline.keras
# 704/704 - 90s - 128ms/step - accuracy: 0.8019 - loss: 0.5869 - val_accuracy: 0.7922 - val_loss: 0.6259 - learning_rate: 6.2500e-05
# Epoch 44/50
#
# Epoch 44: val_accuracy improved from 0.79220 to 0.80220, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp1_baseline.keras
# 704/704 - 84s - 119ms/step - accuracy: 0.7995 - loss: 0.5877 - val_accuracy: 0.8022 - val_loss: 0.6135 - learning_rate: 6.2500e-05
# Epoch 45/50
#
# Epoch 45: val_accuracy did not improve from 0.80220
# 704/704 - 479s - 681ms/step - accuracy: 0.8014 - loss: 0.5822 - val_accuracy: 0.7968 - val_loss: 0.6275 - learning_rate: 6.2500e-05
# Epoch 46/50
#
# Epoch 46: val_accuracy did not improve from 0.80220
# 704/704 - 104s - 148ms/step - accuracy: 0.8024 - loss: 0.5826 - val_accuracy: 0.7974 - val_loss: 0.6249 - learning_rate: 6.2500e-05
# Epoch 47/50
#
# Epoch 47: val_accuracy did not improve from 0.80220
# 704/704 - 98s - 139ms/step - accuracy: 0.8017 - loss: 0.5838 - val_accuracy: 0.7942 - val_loss: 0.6321 - learning_rate: 6.2500e-05
# Epoch 48/50
#
# Epoch 48: val_accuracy did not improve from 0.80220
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 704/704 - 91s - 129ms/step - accuracy: 0.8043 - loss: 0.5754 - val_accuracy: 0.7964 - val_loss: 0.6189 - learning_rate: 6.2500e-05
# Epoch 49/50
#
# Epoch 49: val_accuracy did not improve from 0.80220
# 704/704 - 85s - 120ms/step - accuracy: 0.8019 - loss: 0.5785 - val_accuracy: 0.7998 - val_loss: 0.6123 - learning_rate: 3.1250e-05
# Epoch 50/50
#
# Epoch 50: val_accuracy did not improve from 0.80220
# 704/704 - 82s - 116ms/step - accuracy: 0.8032 - loss: 0.5745 - val_accuracy: 0.7986 - val_loss: 0.6200 - learning_rate: 3.1250e-05
# Restoring model weights from the end of the best epoch: 44.
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\curves_exp1_baseline.png
#
# [exp1_baseline] best val_accuracy = 0.8022, saved to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp1_baseline.keras

# %%
# Experiment 3 — baseline CNN, with 60% of own images mixed into training
splits_with_own = build_splits(include_own_in_training=True)
model_with_own = build_baseline_cnn()
hist_with_own = train_model(model_with_own, run_name='exp3_with_own', splits=splits_with_own)
# Out:
# Added 328 own images to training (new size 45328)
# Epoch 1/50
#
# Epoch 1: val_accuracy improved from None to 0.48700, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp3_with_own.keras
# 709/709 - 90s - 126ms/step - accuracy: 0.4063 - loss: 1.6238 - val_accuracy: 0.4870 - val_loss: 1.4489 - learning_rate: 0.0010
# Epoch 2/50
#
# Epoch 2: val_accuracy improved from 0.48700 to 0.50440, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp3_with_own.keras
# 709/709 - 85s - 120ms/step - accuracy: 0.5275 - loss: 1.3280 - val_accuracy: 0.5044 - val_loss: 1.4332 - learning_rate: 0.0010
# Epoch 3/50
#
# Epoch 3: val_accuracy improved from 0.50440 to 0.61000, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp3_with_own.keras
# 709/709 - 81s - 114ms/step - accuracy: 0.5748 - loss: 1.1998 - val_accuracy: 0.6100 - val_loss: 1.1026 - learning_rate: 0.0010
# Epoch 4/50
#
# Epoch 4: val_accuracy did not improve from 0.61000
# 709/709 - 78s - 111ms/step - accuracy: 0.6064 - loss: 1.1192 - val_accuracy: 0.6062 - val_loss: 1.1025 - learning_rate: 0.0010
# Epoch 5/50
#
# Epoch 5: val_accuracy improved from 0.61000 to 0.64940, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp3_with_own.keras
# 709/709 - 80s - 113ms/step - accuracy: 0.6366 - loss: 1.0503 - val_accuracy: 0.6494 - val_loss: 1.0282 - learning_rate: 0.0010
# Epoch 6/50
#
# Epoch 6: val_accuracy improved from 0.64940 to 0.65480, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp3_with_own.keras
# 709/709 - 79s - 112ms/step - accuracy: 0.6533 - loss: 0.9975 - val_accuracy: 0.6548 - val_loss: 0.9551 - learning_rate: 0.0010
# Epoch 7/50
#
# Epoch 7: val_accuracy improved from 0.65480 to 0.68660, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp3_with_own.keras
# 709/709 - 79s - 111ms/step - accuracy: 0.6702 - loss: 0.9541 - val_accuracy: 0.6866 - val_loss: 0.8854 - learning_rate: 0.0010
# Epoch 8/50
#
# Epoch 8: val_accuracy did not improve from 0.68660
# 709/709 - 78s - 109ms/step - accuracy: 0.6822 - loss: 0.9189 - val_accuracy: 0.5994 - val_loss: 1.1916 - learning_rate: 0.0010
# Epoch 9/50
#
# Epoch 9: val_accuracy improved from 0.68660 to 0.68680, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp3_with_own.keras
# 709/709 - 80s - 112ms/step - accuracy: 0.6907 - loss: 0.8913 - val_accuracy: 0.6868 - val_loss: 0.8850 - learning_rate: 0.0010
# Epoch 10/50
#
# Epoch 10: val_accuracy improved from 0.68680 to 0.69920, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp3_with_own.keras
# 709/709 - 77s - 109ms/step - accuracy: 0.7004 - loss: 0.8727 - val_accuracy: 0.6992 - val_loss: 0.8964 - learning_rate: 0.0010
# Epoch 11/50
#
# Epoch 11: val_accuracy did not improve from 0.69920
# 709/709 - 77s - 109ms/step - accuracy: 0.7092 - loss: 0.8459 - val_accuracy: 0.6802 - val_loss: 0.9292 - learning_rate: 0.0010
# Epoch 12/50
#
# Epoch 12: val_accuracy improved from 0.69920 to 0.71180, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp3_with_own.keras
# 709/709 - 76s - 107ms/step - accuracy: 0.7160 - loss: 0.8288 - val_accuracy: 0.7118 - val_loss: 0.8339 - learning_rate: 0.0010
# Epoch 13/50
#
# Epoch 13: val_accuracy improved from 0.71180 to 0.72100, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp3_with_own.keras
# 709/709 - 80s - 112ms/step - accuracy: 0.7217 - loss: 0.8109 - val_accuracy: 0.7210 - val_loss: 0.8198 - learning_rate: 0.0010
# Epoch 14/50
#
# Epoch 14: val_accuracy improved from 0.72100 to 0.74320, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp3_with_own.keras
# 709/709 - 79s - 111ms/step - accuracy: 0.7263 - loss: 0.7993 - val_accuracy: 0.7432 - val_loss: 0.7456 - learning_rate: 0.0010
# Epoch 15/50
#
# Epoch 15: val_accuracy did not improve from 0.74320
# 709/709 - 79s - 111ms/step - accuracy: 0.7305 - loss: 0.7835 - val_accuracy: 0.7242 - val_loss: 0.8108 - learning_rate: 0.0010
# Epoch 16/50
#
# Epoch 16: val_accuracy did not improve from 0.74320
# 709/709 - 79s - 111ms/step - accuracy: 0.7345 - loss: 0.7747 - val_accuracy: 0.6776 - val_loss: 1.0016 - learning_rate: 0.0010
# Epoch 17/50
#
# Epoch 17: val_accuracy did not improve from 0.74320
# 709/709 - 77s - 108ms/step - accuracy: 0.7419 - loss: 0.7542 - val_accuracy: 0.6912 - val_loss: 0.9812 - learning_rate: 0.0010
# Epoch 18/50
#
# Epoch 18: val_accuracy did not improve from 0.74320
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 709/709 - 76s - 107ms/step - accuracy: 0.7447 - loss: 0.7500 - val_accuracy: 0.7294 - val_loss: 0.7844 - learning_rate: 0.0010
# Epoch 19/50
#
# Epoch 19: val_accuracy did not improve from 0.74320
# 709/709 - 77s - 108ms/step - accuracy: 0.7609 - loss: 0.7025 - val_accuracy: 0.7312 - val_loss: 0.8066 - learning_rate: 5.0000e-04
# Epoch 20/50
#
# Epoch 20: val_accuracy improved from 0.74320 to 0.76020, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp3_with_own.keras
# 709/709 - 78s - 110ms/step - accuracy: 0.7607 - loss: 0.6952 - val_accuracy: 0.7602 - val_loss: 0.7299 - learning_rate: 5.0000e-04
# Epoch 21/50
#
# Epoch 21: val_accuracy did not improve from 0.76020
# 709/709 - 77s - 109ms/step - accuracy: 0.7697 - loss: 0.6824 - val_accuracy: 0.7584 - val_loss: 0.7118 - learning_rate: 5.0000e-04
# Epoch 22/50
#
# Epoch 22: val_accuracy did not improve from 0.76020
# 709/709 - 78s - 110ms/step - accuracy: 0.7666 - loss: 0.6803 - val_accuracy: 0.7592 - val_loss: 0.6970 - learning_rate: 5.0000e-04
# Epoch 23/50
#
# Epoch 23: val_accuracy did not improve from 0.76020
# 709/709 - 79s - 111ms/step - accuracy: 0.7723 - loss: 0.6708 - val_accuracy: 0.7548 - val_loss: 0.7553 - learning_rate: 5.0000e-04
# Epoch 24/50
#
# Epoch 24: val_accuracy improved from 0.76020 to 0.77840, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp3_with_own.keras
# 709/709 - 78s - 109ms/step - accuracy: 0.7733 - loss: 0.6675 - val_accuracy: 0.7784 - val_loss: 0.6502 - learning_rate: 5.0000e-04
# Epoch 25/50
#
# Epoch 25: val_accuracy did not improve from 0.77840
# 709/709 - 80s - 113ms/step - accuracy: 0.7750 - loss: 0.6590 - val_accuracy: 0.7458 - val_loss: 0.7678 - learning_rate: 5.0000e-04
# Epoch 26/50
#
# Epoch 26: val_accuracy did not improve from 0.77840
# 709/709 - 78s - 109ms/step - accuracy: 0.7762 - loss: 0.6539 - val_accuracy: 0.7622 - val_loss: 0.7132 - learning_rate: 5.0000e-04
# Epoch 27/50
#
# Epoch 27: val_accuracy did not improve from 0.77840
# 709/709 - 75s - 106ms/step - accuracy: 0.7783 - loss: 0.6478 - val_accuracy: 0.7656 - val_loss: 0.6947 - learning_rate: 5.0000e-04
# Epoch 28/50
#
# Epoch 28: val_accuracy did not improve from 0.77840
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 709/709 - 79s - 112ms/step - accuracy: 0.7791 - loss: 0.6463 - val_accuracy: 0.7642 - val_loss: 0.7065 - learning_rate: 5.0000e-04
# Epoch 29/50
#
# Epoch 29: val_accuracy did not improve from 0.77840
# 709/709 - 78s - 109ms/step - accuracy: 0.7867 - loss: 0.6270 - val_accuracy: 0.7778 - val_loss: 0.6633 - learning_rate: 2.5000e-04
# Epoch 30/50
#
# Epoch 30: val_accuracy improved from 0.77840 to 0.78420, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp3_with_own.keras
# 709/709 - 76s - 108ms/step - accuracy: 0.7874 - loss: 0.6217 - val_accuracy: 0.7842 - val_loss: 0.6433 - learning_rate: 2.5000e-04
# Epoch 31/50
#
# Epoch 31: val_accuracy improved from 0.78420 to 0.78500, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp3_with_own.keras
# 709/709 - 78s - 110ms/step - accuracy: 0.7895 - loss: 0.6179 - val_accuracy: 0.7850 - val_loss: 0.6401 - learning_rate: 2.5000e-04
# Epoch 32/50
#
# Epoch 32: val_accuracy improved from 0.78500 to 0.78640, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp3_with_own.keras
# 709/709 - 76s - 108ms/step - accuracy: 0.7915 - loss: 0.6126 - val_accuracy: 0.7864 - val_loss: 0.6401 - learning_rate: 2.5000e-04
# Epoch 33/50
#
# Epoch 33: val_accuracy did not improve from 0.78640
# 709/709 - 78s - 110ms/step - accuracy: 0.7928 - loss: 0.6093 - val_accuracy: 0.7774 - val_loss: 0.6848 - learning_rate: 2.5000e-04
# Epoch 34/50
#
# Epoch 34: val_accuracy did not improve from 0.78640
# 709/709 - 77s - 108ms/step - accuracy: 0.7937 - loss: 0.6024 - val_accuracy: 0.7830 - val_loss: 0.6446 - learning_rate: 2.5000e-04
# Epoch 35/50
#
# Epoch 35: val_accuracy did not improve from 0.78640
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 709/709 - 77s - 108ms/step - accuracy: 0.7931 - loss: 0.6063 - val_accuracy: 0.7760 - val_loss: 0.6895 - learning_rate: 2.5000e-04
# Epoch 36/50
#
# Epoch 36: val_accuracy did not improve from 0.78640
# 709/709 - 79s - 111ms/step - accuracy: 0.8022 - loss: 0.5855 - val_accuracy: 0.7854 - val_loss: 0.6524 - learning_rate: 1.2500e-04
# Epoch 37/50
#
# Epoch 37: val_accuracy improved from 0.78640 to 0.79620, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp3_with_own.keras
# 709/709 - 78s - 109ms/step - accuracy: 0.7961 - loss: 0.5960 - val_accuracy: 0.7962 - val_loss: 0.6091 - learning_rate: 1.2500e-04
# Epoch 38/50
#
# Epoch 38: val_accuracy did not improve from 0.79620
# 709/709 - 75s - 106ms/step - accuracy: 0.7981 - loss: 0.5905 - val_accuracy: 0.7930 - val_loss: 0.6171 - learning_rate: 1.2500e-04
# Epoch 39/50
#
# Epoch 39: val_accuracy did not improve from 0.79620
# 709/709 - 78s - 109ms/step - accuracy: 0.7993 - loss: 0.5856 - val_accuracy: 0.7938 - val_loss: 0.6327 - learning_rate: 1.2500e-04
# Epoch 40/50
#
# Epoch 40: val_accuracy improved from 0.79620 to 0.80020, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp3_with_own.keras
# 709/709 - 78s - 110ms/step - accuracy: 0.7997 - loss: 0.5868 - val_accuracy: 0.8002 - val_loss: 0.5953 - learning_rate: 1.2500e-04
# Epoch 41/50
#
# Epoch 41: val_accuracy did not improve from 0.80020
# 709/709 - 77s - 108ms/step - accuracy: 0.8011 - loss: 0.5875 - val_accuracy: 0.7836 - val_loss: 0.6531 - learning_rate: 1.2500e-04
# Epoch 42/50
#
# Epoch 42: val_accuracy did not improve from 0.80020
# 709/709 - 76s - 108ms/step - accuracy: 0.8005 - loss: 0.5855 - val_accuracy: 0.7854 - val_loss: 0.6469 - learning_rate: 1.2500e-04
# Epoch 43/50
#
# Epoch 43: val_accuracy did not improve from 0.80020
# 709/709 - 77s - 108ms/step - accuracy: 0.8036 - loss: 0.5762 - val_accuracy: 0.7894 - val_loss: 0.6212 - learning_rate: 1.2500e-04
# Epoch 44/50
#
# Epoch 44: val_accuracy did not improve from 0.80020
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 709/709 - 80s - 113ms/step - accuracy: 0.8042 - loss: 0.5751 - val_accuracy: 0.7940 - val_loss: 0.6134 - learning_rate: 1.2500e-04
# Epoch 45/50
#
# Epoch 45: val_accuracy did not improve from 0.80020
# 709/709 - 79s - 112ms/step - accuracy: 0.8041 - loss: 0.5783 - val_accuracy: 0.7928 - val_loss: 0.6032 - learning_rate: 6.2500e-05
# Epoch 46/50
#
# Epoch 46: val_accuracy did not improve from 0.80020
# 709/709 - 77s - 109ms/step - accuracy: 0.8028 - loss: 0.5737 - val_accuracy: 0.7946 - val_loss: 0.6053 - learning_rate: 6.2500e-05
# Epoch 47/50
#
# Epoch 47: val_accuracy did not improve from 0.80020
# 709/709 - 78s - 110ms/step - accuracy: 0.8046 - loss: 0.5786 - val_accuracy: 0.7928 - val_loss: 0.6143 - learning_rate: 6.2500e-05
# Epoch 48/50
#
# Epoch 48: val_accuracy did not improve from 0.80020
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 709/709 - 79s - 111ms/step - accuracy: 0.8049 - loss: 0.5708 - val_accuracy: 0.7982 - val_loss: 0.5971 - learning_rate: 6.2500e-05
# Epoch 48: early stopping
# Restoring model weights from the end of the best epoch: 40.
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\curves_exp3_with_own.png
#
# [exp3_with_own] best val_accuracy = 0.8002, saved to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp3_with_own.keras

# %%
# Experiment 5 — MobileNetV2 transfer learning on CIFAR-10
model_transfer = build_transfer_model()
hist_transfer = train_model(model_transfer, run_name='exp5_transfer', splits=splits_cifar)
# Out:
# Epoch 1/50
#
# Epoch 1: val_accuracy improved from None to 0.73680, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp5_transfer.keras
# 704/704 - 115s - 163ms/step - accuracy: 0.5545 - loss: 1.3067 - val_accuracy: 0.7368 - val_loss: 0.7845 - learning_rate: 0.0010
# Epoch 2/50
#
# Epoch 2: val_accuracy improved from 0.73680 to 0.76760, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp5_transfer.keras
# 704/704 - 110s - 157ms/step - accuracy: 0.6279 - loss: 1.0704 - val_accuracy: 0.7676 - val_loss: 0.6870 - learning_rate: 0.0010
# Epoch 3/50
#
# Epoch 3: val_accuracy did not improve from 0.76760
# 704/704 - 104s - 148ms/step - accuracy: 0.6390 - loss: 1.0377 - val_accuracy: 0.7566 - val_loss: 0.7155 - learning_rate: 0.0010
# Epoch 4/50
#
# Epoch 4: val_accuracy improved from 0.76760 to 0.78520, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp5_transfer.keras
# 704/704 - 103s - 146ms/step - accuracy: 0.6389 - loss: 1.0326 - val_accuracy: 0.7852 - val_loss: 0.6320 - learning_rate: 0.0010
# Epoch 5/50
#
# Epoch 5: val_accuracy did not improve from 0.78520
# 704/704 - 107s - 151ms/step - accuracy: 0.6449 - loss: 1.0242 - val_accuracy: 0.7760 - val_loss: 0.6741 - learning_rate: 0.0010
# Epoch 6/50
#
# Epoch 6: val_accuracy did not improve from 0.78520
# 704/704 - 106s - 150ms/step - accuracy: 0.6451 - loss: 1.0240 - val_accuracy: 0.7800 - val_loss: 0.6455 - learning_rate: 0.0010
# Epoch 7/50
#
# Epoch 7: val_accuracy improved from 0.78520 to 0.78940, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp5_transfer.keras
# 704/704 - 103s - 147ms/step - accuracy: 0.6457 - loss: 1.0244 - val_accuracy: 0.7894 - val_loss: 0.6308 - learning_rate: 0.0010
# Epoch 8/50
#
# Epoch 8: val_accuracy did not improve from 0.78940
# 704/704 - 104s - 148ms/step - accuracy: 0.6441 - loss: 1.0297 - val_accuracy: 0.7646 - val_loss: 0.7094 - learning_rate: 0.0010
# Epoch 9/50
#
# Epoch 9: val_accuracy did not improve from 0.78940
# 704/704 - 106s - 150ms/step - accuracy: 0.6470 - loss: 1.0216 - val_accuracy: 0.7742 - val_loss: 0.6828 - learning_rate: 0.0010
# Epoch 10/50
#
# Epoch 10: val_accuracy did not improve from 0.78940
# 704/704 - 104s - 148ms/step - accuracy: 0.6461 - loss: 1.0266 - val_accuracy: 0.7842 - val_loss: 0.6531 - learning_rate: 0.0010
# Epoch 11/50
#
# Epoch 11: val_accuracy did not improve from 0.78940
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 704/704 - 101s - 143ms/step - accuracy: 0.6479 - loss: 1.0142 - val_accuracy: 0.7850 - val_loss: 0.6621 - learning_rate: 0.0010
# Epoch 12/50
#
# Epoch 12: val_accuracy improved from 0.78940 to 0.79400, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp5_transfer.keras
# 704/704 - 106s - 151ms/step - accuracy: 0.6552 - loss: 0.9933 - val_accuracy: 0.7940 - val_loss: 0.6297 - learning_rate: 5.0000e-04
# Epoch 13/50
#
# Epoch 13: val_accuracy did not improve from 0.79400
# 704/704 - 102s - 145ms/step - accuracy: 0.6555 - loss: 0.9890 - val_accuracy: 0.7896 - val_loss: 0.6375 - learning_rate: 5.0000e-04
# Epoch 14/50
#
# Epoch 14: val_accuracy improved from 0.79400 to 0.79420, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp5_transfer.keras
# 704/704 - 105s - 149ms/step - accuracy: 0.6600 - loss: 0.9808 - val_accuracy: 0.7942 - val_loss: 0.6311 - learning_rate: 5.0000e-04
# Epoch 15/50
#
# Epoch 15: val_accuracy improved from 0.79420 to 0.79500, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp5_transfer.keras
# 704/704 - 103s - 147ms/step - accuracy: 0.6543 - loss: 0.9836 - val_accuracy: 0.7950 - val_loss: 0.6326 - learning_rate: 5.0000e-04
# Epoch 16/50
#
# Epoch 16: val_accuracy did not improve from 0.79500
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 704/704 - 105s - 148ms/step - accuracy: 0.6582 - loss: 0.9823 - val_accuracy: 0.7926 - val_loss: 0.6389 - learning_rate: 5.0000e-04
# Epoch 17/50
#
# Epoch 17: val_accuracy improved from 0.79500 to 0.80020, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp5_transfer.keras
# 704/704 - 104s - 147ms/step - accuracy: 0.6630 - loss: 0.9670 - val_accuracy: 0.8002 - val_loss: 0.6094 - learning_rate: 2.5000e-04
# Epoch 18/50
#
# Epoch 18: val_accuracy did not improve from 0.80020
# 704/704 - 102s - 146ms/step - accuracy: 0.6631 - loss: 0.9636 - val_accuracy: 0.7944 - val_loss: 0.6194 - learning_rate: 2.5000e-04
# Epoch 19/50
#
# Epoch 19: val_accuracy did not improve from 0.80020
# 704/704 - 102s - 145ms/step - accuracy: 0.6618 - loss: 0.9634 - val_accuracy: 0.7990 - val_loss: 0.6021 - learning_rate: 2.5000e-04
# Epoch 20/50
#
# Epoch 20: val_accuracy did not improve from 0.80020
# 704/704 - 103s - 147ms/step - accuracy: 0.6606 - loss: 0.9664 - val_accuracy: 0.7946 - val_loss: 0.6108 - learning_rate: 2.5000e-04
# Epoch 21/50
#
# Epoch 21: val_accuracy did not improve from 0.80020
# 704/704 - 102s - 145ms/step - accuracy: 0.6663 - loss: 0.9585 - val_accuracy: 0.7946 - val_loss: 0.6154 - learning_rate: 2.5000e-04
# Epoch 22/50
#
# Epoch 22: val_accuracy did not improve from 0.80020
# 704/704 - 104s - 148ms/step - accuracy: 0.6633 - loss: 0.9580 - val_accuracy: 0.7964 - val_loss: 0.6152 - learning_rate: 2.5000e-04
# Epoch 23/50
#
# Epoch 23: val_accuracy improved from 0.80020 to 0.80040, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp5_transfer.keras
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 704/704 - 103s - 147ms/step - accuracy: 0.6667 - loss: 0.9583 - val_accuracy: 0.8004 - val_loss: 0.6044 - learning_rate: 2.5000e-04
# Epoch 24/50
#
# Epoch 24: val_accuracy did not improve from 0.80040
# 704/704 - 105s - 149ms/step - accuracy: 0.6705 - loss: 0.9514 - val_accuracy: 0.7986 - val_loss: 0.6094 - learning_rate: 1.2500e-04
# Epoch 25/50
#
# Epoch 25: val_accuracy did not improve from 0.80040
# 704/704 - 103s - 146ms/step - accuracy: 0.6702 - loss: 0.9515 - val_accuracy: 0.8000 - val_loss: 0.6039 - learning_rate: 1.2500e-04
# Epoch 26/50
#
# Epoch 26: val_accuracy did not improve from 0.80040
# 704/704 - 103s - 146ms/step - accuracy: 0.6682 - loss: 0.9556 - val_accuracy: 0.8000 - val_loss: 0.6034 - learning_rate: 1.2500e-04
# Epoch 27/50
#
# Epoch 27: val_accuracy improved from 0.80040 to 0.80200, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp5_transfer.keras
# 704/704 - 104s - 148ms/step - accuracy: 0.6663 - loss: 0.9584 - val_accuracy: 0.8020 - val_loss: 0.5980 - learning_rate: 1.2500e-04
# Epoch 28/50
#
# Epoch 28: val_accuracy did not improve from 0.80200
# 704/704 - 104s - 148ms/step - accuracy: 0.6677 - loss: 0.9518 - val_accuracy: 0.7990 - val_loss: 0.6092 - learning_rate: 1.2500e-04
# Epoch 29/50
#
# Epoch 29: val_accuracy did not improve from 0.80200
# 704/704 - 105s - 149ms/step - accuracy: 0.6698 - loss: 0.9510 - val_accuracy: 0.8014 - val_loss: 0.5999 - learning_rate: 1.2500e-04
# Epoch 30/50
#
# Epoch 30: val_accuracy did not improve from 0.80200
# 704/704 - 103s - 146ms/step - accuracy: 0.6671 - loss: 0.9555 - val_accuracy: 0.8004 - val_loss: 0.6013 - learning_rate: 1.2500e-04
# Epoch 31/50
#
# Epoch 31: val_accuracy did not improve from 0.80200
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 704/704 - 103s - 146ms/step - accuracy: 0.6697 - loss: 0.9556 - val_accuracy: 0.8006 - val_loss: 0.6058 - learning_rate: 1.2500e-04
# Epoch 32/50
#
# Epoch 32: val_accuracy improved from 0.80200 to 0.80260, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp5_transfer.keras
# 704/704 - 111s - 157ms/step - accuracy: 0.6726 - loss: 0.9434 - val_accuracy: 0.8026 - val_loss: 0.5997 - learning_rate: 6.2500e-05
# Epoch 33/50
#
# Epoch 33: val_accuracy did not improve from 0.80260
# 704/704 - 104s - 148ms/step - accuracy: 0.6717 - loss: 0.9465 - val_accuracy: 0.8010 - val_loss: 0.6055 - learning_rate: 6.2500e-05
# Epoch 34/50
#
# Epoch 34: val_accuracy did not improve from 0.80260
# 704/704 - 105s - 149ms/step - accuracy: 0.6698 - loss: 0.9439 - val_accuracy: 0.8016 - val_loss: 0.6022 - learning_rate: 6.2500e-05
# Epoch 35/50
#
# Epoch 35: val_accuracy did not improve from 0.80260
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 704/704 - 103s - 146ms/step - accuracy: 0.6694 - loss: 0.9473 - val_accuracy: 0.8026 - val_loss: 0.6008 - learning_rate: 6.2500e-05
# Epoch 36/50
#
# Epoch 36: val_accuracy improved from 0.80260 to 0.80480, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp5_transfer.keras
# 704/704 - 105s - 149ms/step - accuracy: 0.6704 - loss: 0.9443 - val_accuracy: 0.8048 - val_loss: 0.5970 - learning_rate: 3.1250e-05
# Epoch 37/50
#
# Epoch 37: val_accuracy improved from 0.80480 to 0.80560, saving model to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp5_transfer.keras
# 704/704 - 105s - 149ms/step - accuracy: 0.6710 - loss: 0.9445 - val_accuracy: 0.8056 - val_loss: 0.5943 - learning_rate: 3.1250e-05
# Epoch 38/50
#
# Epoch 38: val_accuracy did not improve from 0.80560
# 704/704 - 103s - 147ms/step - accuracy: 0.6741 - loss: 0.9418 - val_accuracy: 0.8054 - val_loss: 0.5958 - learning_rate: 3.1250e-05
# Epoch 39/50
#
# Epoch 39: val_accuracy did not improve from 0.80560
# 704/704 - 105s - 149ms/step - accuracy: 0.6732 - loss: 0.9417 - val_accuracy: 0.8030 - val_loss: 0.5977 - learning_rate: 3.1250e-05
# Epoch 40/50
#
# Epoch 40: val_accuracy did not improve from 0.80560
# 704/704 - 106s - 151ms/step - accuracy: 0.6706 - loss: 0.9473 - val_accuracy: 0.8040 - val_loss: 0.5968 - learning_rate: 3.1250e-05
# Epoch 41/50
#
# Epoch 41: val_accuracy did not improve from 0.80560
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 704/704 - 105s - 149ms/step - accuracy: 0.6721 - loss: 0.9397 - val_accuracy: 0.8034 - val_loss: 0.5983 - learning_rate: 3.1250e-05
# Epoch 42/50
#
# Epoch 42: val_accuracy did not improve from 0.80560
# 704/704 - 104s - 148ms/step - accuracy: 0.6701 - loss: 0.9429 - val_accuracy: 0.8052 - val_loss: 0.5940 - learning_rate: 1.5625e-05
# Epoch 43/50
#
# Epoch 43: val_accuracy did not improve from 0.80560
# 704/704 - 104s - 147ms/step - accuracy: 0.6733 - loss: 0.9399 - val_accuracy: 0.8052 - val_loss: 0.5929 - learning_rate: 1.5625e-05
# Epoch 44/50
#
# Epoch 44: val_accuracy did not improve from 0.80560
# 704/704 - 104s - 148ms/step - accuracy: 0.6728 - loss: 0.9392 - val_accuracy: 0.8054 - val_loss: 0.5943 - learning_rate: 1.5625e-05
# Epoch 45/50
#
# Epoch 45: val_accuracy did not improve from 0.80560
# 704/704 - 104s - 148ms/step - accuracy: 0.6723 - loss: 0.9439 - val_accuracy: 0.8052 - val_loss: 0.5938 - learning_rate: 1.5625e-05
# Epoch 45: early stopping
# Restoring model weights from the end of the best epoch: 37.
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\curves_exp5_transfer.png
#
# [exp5_transfer] best val_accuracy = 0.8056, saved to C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\models\exp5_transfer.keras

# %% [markdown]
# ## 8. Evaluation utilities (rubric §4)
#
# For every trained model we compute:
#
# * **Accuracy** — fraction of correct predictions (single headline number).
# * **Macro-F1** — our primary optimising metric (treats every class equally; robust to imbalance).
# * **Per-class precision/recall/F1** — saved to CSV (rubric §4.3).
# * **Confusion matrix** — PNG; reveals which classes the model confuses (rubric §4.5).
# * **Sample-prediction grid** — PNG; 25 random examples with green/red title for correct/wrong.
# * **Worst mispredictions** — PNG of the 10 images where the model was most confidently wrong (rubric §4.4).

# %%
def compute_metrics(y_true, y_pred):
    acc = accuracy_score(y_true, y_pred)
    prec, rec, f1, sup = precision_recall_fscore_support(
        y_true, y_pred, labels=list(range(NUM_CLASSES)), zero_division=0)
    return {
        'accuracy': float(acc),
        'precision_macro': float(prec.mean()),
        'recall_macro':    float(rec.mean()),
        'f1_macro':        float(f1.mean()),
        'per_class': {'class': CLASS_NAMES,
                      'precision': prec.tolist(),
                      'recall':    rec.tolist(),
                      'f1':        f1.tolist(),
                      'support':   sup.tolist()},
    }

def plot_confusion_matrix(cm, out_path, title):
    fig, ax = plt.subplots(figsize=(7, 6))
    im = ax.imshow(cm, cmap='Blues')
    ax.set_title(title); ax.set_xlabel('Predicted'); ax.set_ylabel('True')
    n = len(CLASS_NAMES)
    ax.set_xticks(range(n)); ax.set_xticklabels(CLASS_NAMES, rotation=45, ha='right')
    ax.set_yticks(range(n)); ax.set_yticklabels(CLASS_NAMES)
    thresh = cm.max() / 2.0 if cm.max() > 0 else 1
    for i in range(n):
        for j in range(n):
            ax.text(j, i, int(cm[i, j]), ha='center', va='center',
                    color='white' if cm[i, j] > thresh else 'black', fontsize=9)
    fig.colorbar(im, ax=ax); fig.tight_layout()
    fig.savefig(out_path, dpi=150); plt.show()
    print('saved', out_path)

def plot_sample_predictions(model, x, y, out_path, n=25):
    if len(x) == 0:
        return
    rng = np.random.default_rng(0)
    idx = rng.choice(len(x), size=min(n, len(x)), replace=False)
    preds = model.predict(x[idx], verbose=0).argmax(axis=1)
    rows = int(np.ceil(len(idx) / 5))
    fig, axes = plt.subplots(rows, 5, figsize=(12, 2.5 * rows))
    axes = axes.flatten()
    for i, ax in enumerate(axes):
        if i >= len(idx):
            ax.axis('off'); continue
        ax.imshow(x[idx[i]])
        t = CLASS_NAMES[y[idx[i]]]; p = CLASS_NAMES[preds[i]]
        ok = (y[idx[i]] == preds[i])
        ax.set_title(f'T:{t}\nP:{p}', color=('green' if ok else 'red'), fontsize=9)
        ax.axis('off')
    fig.tight_layout(); fig.savefig(out_path, dpi=150); plt.show()
    print('saved', out_path)

def plot_misclassified(model, x, y, out_path, n=10):
    if len(x) == 0:
        return
    probs = model.predict(x, verbose=0)
    preds = probs.argmax(axis=1)
    wrong = np.where(preds != y)[0]
    if len(wrong) == 0:
        print('No misclassifications — perfect accuracy.')
        return
    wrong_conf = probs[wrong, preds[wrong]]
    worst = wrong[np.argsort(-wrong_conf)][:n]
    cols = 5; rows = int(np.ceil(len(worst) / cols))
    fig, axes = plt.subplots(rows, cols, figsize=(12, 2.8 * rows))
    axes = np.array(axes).flatten()
    for i, ax in enumerate(axes):
        if i >= len(worst):
            ax.axis('off'); continue
        idx = worst[i]
        ax.imshow(x[idx])
        ax.set_title(f'T:{CLASS_NAMES[y[idx]]}\nP:{CLASS_NAMES[preds[idx]]} ({probs[idx, preds[idx]]:.2f})',
                     color='red', fontsize=9)
        ax.axis('off')
    fig.tight_layout(); fig.savefig(out_path, dpi=150); plt.show()
    print('saved', out_path)

def evaluate_split(model, x, y, split_name: str, run_name: str):
    if len(x) == 0:
        print(f'split {split_name!r} is empty — skipping')
        return None
    preds = model.predict(x, verbose=0).argmax(axis=1)
    metrics = compute_metrics(y, preds)
    print(f'\n--- {split_name} ({run_name}) ---')
    print(classification_report(y, preds, target_names=CLASS_NAMES, digits=3, zero_division=0))
    pc = metrics['per_class']
    pd.DataFrame({
        'class': pc['class'], 'precision': pc['precision'],
        'recall': pc['recall'], 'f1': pc['f1'], 'support': pc['support'],
    }).to_csv(TABLES_DIR / f'metrics_{split_name}_{run_name}.csv', index=False)
    cm = confusion_matrix(y, preds, labels=list(range(NUM_CLASSES)))
    plot_confusion_matrix(cm,
                          FIGURES_DIR / f'confusion_matrix_{split_name}_{run_name}.png',
                          title=f'Confusion Matrix — {split_name} — {run_name}')
    return metrics

# %%
def evaluate_run(run_name: str):
    """Load the saved model for a run and evaluate it on CIFAR-test and own-test."""
    model_path = MODELS_DIR / f'{run_name}.keras'
    if not model_path.exists():
        print(f'no model file at {model_path} — train first.')
        return None
    model = load_model(model_path)
    splits = build_splits(include_own_in_training=False)
    m_cifar = evaluate_split(model, *splits['test_cifar'], 'cifar', run_name)
    m_own   = evaluate_split(model, *splits['test_own'],   'own',   run_name)
    plot_sample_predictions(model, *splits['test_cifar'],
                            FIGURES_DIR / f'sample_predictions_{run_name}.png')
    plot_misclassified(model, *splits['test_cifar'],
                       FIGURES_DIR / f'misclassified_{run_name}.png')
    rows = []
    for name, m in [('cifar', m_cifar), ('own', m_own)]:
        if m is None:
            continue
        rows.append({'run': run_name, 'split': name,
                     'accuracy': m['accuracy'],
                     'precision_macro': m['precision_macro'],
                     'recall_macro':    m['recall_macro'],
                     'f1_macro':        m['f1_macro']})
    df = pd.DataFrame(rows)
    df.to_csv(TABLES_DIR / f'summary_{run_name}.csv', index=False)
    return df

summaries = []
for run in ('exp1_baseline', 'exp3_with_own', 'exp5_transfer'):
    s = evaluate_run(run)
    if s is not None:
        summaries.append(s)
if summaries:
    big = pd.concat(summaries, ignore_index=True)
    big.to_csv(TABLES_DIR / 'summary_all.csv', index=False)
    print('\n=== Comparison across runs (rubric §3.8) ===')
    print(big.to_string(index=False))
    print('\nsaved', TABLES_DIR / 'summary_all.csv')
# Out:
# --- cifar (exp1_baseline) ---
#               precision    recall  f1-score   support
#
#     airplane      0.822     0.833     0.828      1000
#   automobile      0.889     0.936     0.912      1000
#         bird      0.776     0.694     0.733      1000
#          cat      0.733     0.552     0.630      1000
#         deer      0.785     0.692     0.735      1000
#          dog      0.854     0.602     0.706      1000
#         frog      0.568     0.951     0.711      1000
#        horse      0.863     0.821     0.842      1000
#         ship      0.907     0.870     0.888      1000
#        truck      0.818     0.913     0.863      1000
#
#     accuracy                          0.786     10000
#    macro avg      0.802     0.786     0.785     10000
# weighted avg      0.802     0.786     0.785     10000
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\confusion_matrix_cifar_exp1_baseline.png
#
# --- own (exp1_baseline) ---
#               precision    recall  f1-score   support
#
#     airplane      0.604     0.784     0.682        37
#   automobile      0.904     0.855     0.879        55
#         bird      0.694     0.632     0.662        68
#          cat      0.789     0.577     0.667        78
#         deer      0.676     0.735     0.704        68
#          dog      0.743     0.491     0.591        53
#         frog      0.571     0.821     0.674        78
#        horse      0.773     0.618     0.687        55
#         ship      0.862     0.962     0.909        26
#        truck      0.794     0.931     0.857        29
#
#     accuracy                          0.713       547
#    macro avg      0.741     0.740     0.731       547
# weighted avg      0.729     0.713     0.710       547
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\confusion_matrix_own_exp1_baseline.png
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\sample_predictions_exp1_baseline.png
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\misclassified_exp1_baseline.png
#
# --- cifar (exp3_with_own) ---
#               precision    recall  f1-score   support
#
#     airplane      0.840     0.846     0.843      1000
#   automobile      0.896     0.909     0.903      1000
#         bird      0.812     0.728     0.768      1000
#          cat      0.723     0.628     0.672      1000
#         deer      0.831     0.746     0.786      1000
#          dog      0.855     0.611     0.713      1000
#         frog      0.680     0.936     0.788      1000
#        horse      0.853     0.856     0.854      1000
#         ship      0.894     0.887     0.891      1000
#        truck      0.751     0.923     0.828      1000
#
#     accuracy                          0.807     10000
#    macro avg      0.814     0.807     0.805     10000
# weighted avg      0.814     0.807     0.805     10000
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\confusion_matrix_cifar_exp3_with_own.png
#
# --- own (exp3_with_own) ---
#               precision    recall  f1-score   support
#
#     airplane      0.592     0.784     0.674        37
#   automobile      0.902     0.836     0.868        55
#         bird      0.597     0.632     0.614        68
#          cat      0.794     0.641     0.709        78
#         deer      0.714     0.735     0.725        68
#          dog      0.744     0.547     0.630        53
#         frog      0.692     0.692     0.692        78
#        horse      0.811     0.782     0.796        55
#         ship      0.862     0.962     0.909        26
#        truck      0.628     0.931     0.750        29
#
#     accuracy                          0.724       547
#    macro avg      0.734     0.754     0.737       547
# weighted avg      0.734     0.724     0.723       547
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\confusion_matrix_own_exp3_with_own.png
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\sample_predictions_exp3_with_own.png
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\misclassified_exp3_with_own.png
#
# --- cifar (exp5_transfer) ---
#               precision    recall  f1-score   support
#
#     airplane      0.806     0.851     0.828      1000
#   automobile      0.844     0.939     0.889      1000
#         bird      0.852     0.683     0.758      1000
#          cat      0.749     0.581     0.654      1000
#         deer      0.869     0.650     0.744      1000
#          dog      0.773     0.720     0.745      1000
#         frog      0.701     0.928     0.799      1000
#        horse      0.742     0.870     0.801      1000
#         ship      0.905     0.829     0.865      1000
#        truck      0.792     0.920     0.851      1000
#
#     accuracy                          0.797     10000
#    macro avg      0.803     0.797     0.793     10000
# weighted avg      0.803     0.797     0.793     10000
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\confusion_matrix_cifar_exp5_transfer.png
#
# --- own (exp5_transfer) ---
#               precision    recall  f1-score   support
#
#     airplane      0.493     0.892     0.635        37
#   automobile      0.942     0.891     0.916        55
#         bird      0.750     0.574     0.650        68
#          cat      0.766     0.628     0.690        78
#         deer      0.875     0.721     0.790        68
#          dog      0.625     0.566     0.594        53
#         frog      0.803     0.731     0.765        78
#        horse      0.646     0.764     0.700        55
#         ship      0.629     0.846     0.721        26
#        truck      0.757     0.966     0.848        29
#
#     accuracy                          0.728       547
#    macro avg      0.728     0.758     0.731       547
# weighted avg      0.749     0.728     0.729       547
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\confusion_matrix_own_exp5_transfer.png
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\sample_predictions_exp5_transfer.png
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\misclassified_exp5_transfer.png
#
# === Comparison across runs (rubric §3.8) ===
#           run split  accuracy  precision_macro  recall_macro  f1_macro
# exp1_baseline cifar  0.786400         0.801573      0.786400  0.784769
# exp1_baseline   own  0.712980         0.740991      0.740473  0.731098
# exp3_with_own cifar  0.807000         0.813501      0.807000  0.804521
# exp3_with_own   own  0.723949         0.733615      0.754269  0.736862
# exp5_transfer cifar  0.797100         0.803190      0.797100  0.793446
# exp5_transfer   own  0.727605         0.728477      0.757724  0.730992
#
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\tables\summary_all.csv

# %% [markdown]
# ## 9. Hyperparameter tuning (rubric §3.4)
#
# Small grid over learning rate and dropout, with shorter training per trial. Each row of the resulting CSV is a
# run; the best row is the winning configuration.

# %%
def hp_grid_search(epochs_per_trial: int = 8, short: bool = True):
    learning_rates = [1e-3, 5e-4] if short else [1e-3, 5e-4, 1e-4]
    dropouts       = [0.3, 0.5]
    combos = list(itertools.product(learning_rates, dropouts))
    print(f'Running {len(combos)} HP trials with {epochs_per_trial} epochs each')

    results = []
    for i, (lr, drop) in enumerate(combos, start=1):
        print(f'\n=== trial {i}/{len(combos)} : lr={lr}  dropout={drop} ===')
        m = build_baseline_cnn(learning_rate=lr, dropout=drop)
        h = m.fit(x_train, y_train, validation_data=(x_val, y_val),
                  batch_size=BATCH_SIZE, epochs=epochs_per_trial, verbose=2,
                  callbacks=[EarlyStopping(monitor='val_accuracy', patience=3,
                                           restore_best_weights=True)])
        best = float(max(h.history['val_accuracy']))
        results.append({'trial': i, 'learning_rate': lr, 'dropout': drop,
                        'best_val_accuracy': best,
                        'final_train_accuracy': float(h.history['accuracy'][-1]),
                        'final_val_accuracy':   float(h.history['val_accuracy'][-1])})
    df = pd.DataFrame(results).sort_values('best_val_accuracy', ascending=False).reset_index(drop=True)
    df.to_csv(TABLES_DIR / 'hp_results.csv', index=False)
    best_row = df.iloc[0].to_dict()
    with open(TABLES_DIR / 'hp_best.json', 'w') as fp:
        json.dump(best_row, fp, indent=2)
    print('\nBest combo:', best_row)
    return df

hp_results = hp_grid_search(epochs_per_trial=8, short=True)
hp_results
# Out:
# Running 4 HP trials with 8 epochs each
#
# === trial 1/4 : lr=0.001  dropout=0.3 ===
# Epoch 1/8
# 704/704 - 84s - 119ms/step - accuracy: 0.4338 - loss: 1.5475 - val_accuracy: 0.4494 - val_loss: 1.7075
# Epoch 2/8
# 704/704 - 84s - 120ms/step - accuracy: 0.5618 - loss: 1.2299 - val_accuracy: 0.5750 - val_loss: 1.2719
# Epoch 3/8
# 704/704 - 78s - 111ms/step - accuracy: 0.6161 - loss: 1.0951 - val_accuracy: 0.6154 - val_loss: 1.1365
# Epoch 4/8
# 704/704 - 78s - 110ms/step - accuracy: 0.6496 - loss: 1.0050 - val_accuracy: 0.5344 - val_loss: 1.5521
# Epoch 5/8
# 704/704 - 78s - 111ms/step - accuracy: 0.6707 - loss: 0.9378 - val_accuracy: 0.6514 - val_loss: 1.0108
# Epoch 6/8
# 704/704 - 79s - 113ms/step - accuracy: 0.6933 - loss: 0.8844 - val_accuracy: 0.6840 - val_loss: 0.9430
# Epoch 7/8
# 704/704 - 78s - 111ms/step - accuracy: 0.7052 - loss: 0.8475 - val_accuracy: 0.6960 - val_loss: 0.9098
# Epoch 8/8
# 704/704 - 78s - 110ms/step - accuracy: 0.7185 - loss: 0.8132 - val_accuracy: 0.7138 - val_loss: 0.8625
#
# === trial 2/4 : lr=0.001  dropout=0.5 ===
# Epoch 1/8
# 704/704 - 81s - 115ms/step - accuracy: 0.4070 - loss: 1.6266 - val_accuracy: 0.3446 - val_loss: 2.2030
# Epoch 2/8
# 704/704 - 77s - 110ms/step - accuracy: 0.5231 - loss: 1.3336 - val_accuracy: 0.5000 - val_loss: 1.4935
# Epoch 3/8
# 704/704 - 77s - 110ms/step - accuracy: 0.5745 - loss: 1.2081 - val_accuracy: 0.4488 - val_loss: 1.8223
# Epoch 4/8
# 704/704 - 76s - 108ms/step - accuracy: 0.6072 - loss: 1.1192 - val_accuracy: 0.5524 - val_loss: 1.3485
# Epoch 5/8
# 704/704 - 76s - 108ms/step - accuracy: 0.6345 - loss: 1.0544 - val_accuracy: 0.6192 - val_loss: 1.1117
# Epoch 6/8
# 704/704 - 77s - 109ms/step - accuracy: 0.6552 - loss: 0.9930 - val_accuracy: 0.6348 - val_loss: 1.0781
# Epoch 7/8
# 704/704 - 78s - 111ms/step - accuracy: 0.6711 - loss: 0.9556 - val_accuracy: 0.6418 - val_loss: 1.0706
# Epoch 8/8
# 704/704 - 74s - 105ms/step - accuracy: 0.6827 - loss: 0.9212 - val_accuracy: 0.6786 - val_loss: 0.9916
#
# === trial 3/4 : lr=0.0005  dropout=0.3 ===
# Epoch 1/8
# 704/704 - 80s - 113ms/step - accuracy: 0.4093 - loss: 1.6140 - val_accuracy: 0.4572 - val_loss: 1.5921
# Epoch 2/8
# 704/704 - 79s - 112ms/step - accuracy: 0.5346 - loss: 1.3100 - val_accuracy: 0.4454 - val_loss: 1.9545
# Epoch 3/8
# 704/704 - 79s - 112ms/step - accuracy: 0.5898 - loss: 1.1629 - val_accuracy: 0.5566 - val_loss: 1.3644
# Epoch 4/8
# 704/704 - 76s - 108ms/step - accuracy: 0.6288 - loss: 1.0640 - val_accuracy: 0.5482 - val_loss: 1.4597
# Epoch 5/8
# 704/704 - 76s - 108ms/step - accuracy: 0.6506 - loss: 0.9926 - val_accuracy: 0.5132 - val_loss: 1.8124
# Epoch 6/8
# 704/704 - 80s - 113ms/step - accuracy: 0.6751 - loss: 0.9326 - val_accuracy: 0.6176 - val_loss: 1.1755
# Epoch 7/8
# 704/704 - 76s - 108ms/step - accuracy: 0.6882 - loss: 0.8974 - val_accuracy: 0.6224 - val_loss: 1.2163
# Epoch 8/8
# 704/704 - 77s - 109ms/step - accuracy: 0.7016 - loss: 0.8595 - val_accuracy: 0.6374 - val_loss: 1.1159
#
# === trial 4/4 : lr=0.0005  dropout=0.5 ===
# Epoch 1/8
# 704/704 - 79s - 112ms/step - accuracy: 0.3868 - loss: 1.6759 - val_accuracy: 0.4402 - val_loss: 1.7014
# Epoch 2/8
# 704/704 - 75s - 107ms/step - accuracy: 0.5067 - loss: 1.3796 - val_accuracy: 0.4558 - val_loss: 1.6015
# Epoch 3/8
# 704/704 - 78s - 111ms/step - accuracy: 0.5588 - loss: 1.2462 - val_accuracy: 0.4680 - val_loss: 1.6356
# Epoch 4/8
# 704/704 - 75s - 106ms/step - accuracy: 0.5896 - loss: 1.1588 - val_accuracy: 0.5030 - val_loss: 1.5473
# Epoch 5/8
# 704/704 - 78s - 111ms/step - accuracy: 0.6181 - loss: 1.0891 - val_accuracy: 0.5446 - val_loss: 1.4952
# Epoch 6/8
# 704/704 - 78s - 111ms/step - accuracy: 0.6422 - loss: 1.0332 - val_accuracy: 0.5408 - val_loss: 1.3999
# Epoch 7/8
# 704/704 - 76s - 108ms/step - accuracy: 0.6590 - loss: 0.9865 - val_accuracy: 0.5968 - val_loss: 1.2530
# Epoch 8/8
# 704/704 - 76s - 108ms/step - accuracy: 0.6688 - loss: 0.9583 - val_accuracy: 0.6100 - val_loss: 1.2213
#
# Best combo: {'trial': 1.0, 'learning_rate': 0.001, 'dropout': 0.3, 'best_val_accuracy': 0.7138000130653381, 'final_train_accuracy': 0.7185333371162415, 'final_val_accuracy': 0.7138000130653381}
#    trial  learning_rate  dropout  best_val_accuracy  final_train_accuracy  \
# 0      1         0.0010      0.3             0.7138              0.718533
# 1      2         0.0010      0.5             0.6786              0.682667
# 2      3         0.0005      0.3             0.6374              0.701600
# 3      4         0.0005      0.5             0.6100              0.668800
#
#    final_val_accuracy
# 0              0.7138
# 1              0.6786
# 2              0.6374
# 3              0.6100

# %% [markdown]
# ## 10. Grad-CAM explainability (rubric §5.1)
#
# Grad-CAM produces a heatmap that highlights which pixels pushed the model toward its prediction. Red areas
# in the overlay are the parts of the image the model paid most attention to. We pick three confidently-correct
# and three confidently-wrong examples from the CIFAR test set so the report has interpretable evidence
# (rubric §5.2).

# %%
def find_last_conv_layer(model):
    for layer in reversed(model.layers):
        if isinstance(layer, tf.keras.layers.Conv2D):
            return layer.name, model
    for layer in reversed(model.layers):
        if hasattr(layer, 'layers'):
            for sub in reversed(layer.layers):
                if isinstance(sub, tf.keras.layers.Conv2D):
                    return sub.name, layer
    raise ValueError('no Conv2D layer found')

def compute_gradcam(model, img_array, class_idx):
    last_name, parent = find_last_conv_layer(model)
    last_layer = parent.get_layer(last_name)
    grad_model = Model(inputs=model.inputs, outputs=[last_layer.output, model.output])
    with tf.GradientTape() as tape:
        conv_out, preds = grad_model(img_array, training=False)
        score = preds[:, class_idx]
    grads = tape.gradient(score, conv_out)
    pooled = tf.reduce_mean(grads, axis=(0, 1, 2))
    heatmap = tf.squeeze(conv_out[0] @ pooled[..., tf.newaxis])
    heatmap = tf.maximum(heatmap, 0)
    m = tf.reduce_max(heatmap)
    if m > 0:
        heatmap /= m
    return heatmap.numpy()

def plot_gradcam(img, heatmap, true_lbl, pred_lbl, conf, out_path):
    fig, axes = plt.subplots(1, 3, figsize=(9, 3.5))
    axes[0].imshow(img); axes[0].set_title(f'Original\nTrue: {true_lbl}'); axes[0].axis('off')
    axes[1].imshow(heatmap, cmap='jet'); axes[1].set_title('Grad-CAM heatmap'); axes[1].axis('off')
    big = tf.image.resize(heatmap[..., np.newaxis], (img.shape[0], img.shape[1])).numpy()[..., 0]
    axes[2].imshow(img); axes[2].imshow(big, cmap='jet', alpha=0.5)
    color = 'green' if (true_lbl == pred_lbl) else 'red'
    axes[2].set_title(f'Overlay\nPred: {pred_lbl} ({conf:.2f})', color=color)
    axes[2].axis('off')
    fig.tight_layout(); fig.savefig(out_path, dpi=150); plt.show()

def run_gradcam(run_name: str, n_correct=3, n_wrong=3):
    model_path = MODELS_DIR / f'{run_name}.keras'
    if not model_path.exists():
        print('no model:', model_path); return
    model = load_model(model_path)
    n_sub = min(2000, len(x_test))
    probs = model.predict(x_test[:n_sub], verbose=0)
    preds = probs.argmax(axis=1)
    correct = np.where(preds == y_test[:n_sub])[0]
    wrong   = np.where(preds != y_test[:n_sub])[0]
    correct_pick = correct[np.argsort(-probs[correct, preds[correct]])][:n_correct]
    wrong_pick   = (wrong[np.argsort(-probs[wrong, preds[wrong]])][:n_wrong]
                    if len(wrong) > 0 else np.array([], dtype=int))
    for label, indices in [('correct', correct_pick), ('wrong', wrong_pick)]:
        for rank, idx in enumerate(indices, start=1):
            img = x_test[idx]
            batch = img[np.newaxis, ...].astype('float32')
            pred_cls = int(preds[idx])
            heatmap = compute_gradcam(model, batch, class_idx=pred_cls)
            out = FIGURES_DIR / f'gradcam_{run_name}_{label}_{rank}.png'
            plot_gradcam(img, heatmap, CLASS_NAMES[int(y_test[idx])],
                         CLASS_NAMES[pred_cls], float(probs[idx, pred_cls]), out)
            print('saved', out)

# Run on the best model. Change to 'exp5_transfer' or 'exp3_with_own' if you prefer.
run_gradcam('exp1_baseline')
# Out:
# C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\.venv\lib\site-packages\keras\src\models\functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input_layer_5']
# Received: inputs=Tensor(shape=(1, 32, 32, 3))
#   warnings.warn(msg)
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\gradcam_exp1_baseline_correct_1.png
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\gradcam_exp1_baseline_correct_2.png
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\gradcam_exp1_baseline_correct_3.png
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\gradcam_exp1_baseline_wrong_1.png
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\gradcam_exp1_baseline_wrong_2.png
# saved C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\reports\figures\gradcam_exp1_baseline_wrong_3.png

# %% [markdown]
# ## 11. Predict a single image
#
# This is the “inference endpoint” — give it any image path and it returns the predicted class plus the full
# probability vector. Useful for the demo + AI-server deployment.

# %%
def predict_image(image_path, run_name: str = 'exp1_baseline', show: bool = True):
    model_path = MODELS_DIR / f'{run_name}.keras'
    if not model_path.exists():
        raise FileNotFoundError(f'no model at {model_path} — train first.')
    model = load_model(model_path)
    img_pil = Image.open(image_path).convert('RGB').resize((IMG_SIZE, IMG_SIZE))
    arr = np.asarray(img_pil, dtype=np.uint8)[np.newaxis, ...]
    probs = model.predict(arr, verbose=0)[0]
    top = int(probs.argmax())
    print(f'\nPrediction for {image_path}')
    print(f'  Class      : {CLASS_NAMES[top]} (index {top})')
    print(f'  Confidence : {probs[top]:.2f}')
    print('  All probabilities:')
    for i, name in enumerate(CLASS_NAMES):
        marker = '   <-- predicted' if i == top else ''
        print(f'    {name:10s}: {probs[i]:.2f}{marker}')
    if show:
        plt.figure(figsize=(3, 3))
        plt.imshow(img_pil); plt.axis('off')
        plt.title(f'pred: {CLASS_NAMES[top]} ({probs[top]:.2f})')
        plt.show()
    return CLASS_NAMES[top], float(probs[top]), {CLASS_NAMES[i]: float(probs[i]) for i in range(NUM_CLASSES)}

# --- Example: predict the first own-image of class cat (3) if any exists ---
cat_dir = OWN_DIR / '3_cat'
example = next((f for f in sorted(cat_dir.iterdir())
                if f.suffix.lower() in SUPPORTED_EXT), None) if cat_dir.exists() else None
if example is not None:
    predict_image(example, run_name='exp1_baseline')
else:
    print('No example image found in data/own/3_cat/. Skipping example call.')
# Out:
# Prediction for C:\Users\ahmad\OneDrive\Desktop\Persöhnliche_DOKU\cifar_vision_project\data\own\3_cat\000001.jpg
#   Class      : cat (index 3)
#   Confidence : 0.96
#   All probabilities:
#     airplane  : 0.00
#     automobile: 0.00
#     bird      : 0.00
#     cat       : 0.96   <-- predicted
#     deer      : 0.00
#     dog       : 0.01
#     frog      : 0.02
#     horse     : 0.00
#     ship      : 0.00
#     truck     : 0.00

# %% [markdown]
# ## 12. Summary, ethics & report tips
#
# You now have everything the rubric asks for:
#
# | Rubric item | Where to find the evidence |
# |-------------|----------------------------|
# | 2.2 EDA | `reports/figures/eda_*.png`, `reports/tables/eda_class_distribution.csv` |
# | 2.4 Preprocessing reproducible | The cleanup + `Rescaling` layer in this notebook |
# | 2.5 Train/val/test split | `load_cifar10()` (45k/5k/10k, fixed seed 42) |
# | 3.1 Baseline model | `models/exp1_baseline.keras` + `reports/figures/curves_exp1_baseline.png` |
# | 3.2 Two approaches compared | `exp1_baseline.keras` vs `exp5_transfer.keras` |
# | 3.4 HP tuning | `reports/tables/hp_results.csv`, `hp_best.json` |
# | 3.7 Experiments tracked | `reports/tables/config_*.json`, `history_*.csv`, `summary_*.csv` |
# | 4.2 Performance reported | `summary_*.csv`, `metrics_*.csv` |
# | 4.3 Per-class breakdown | `metrics_*_*.csv` |
# | 4.4 Mispredictions analysed | `reports/figures/misclassified_*.png` |
# | 4.6 Robustness on own photos | `summary_*.csv` rows with `split=own` |
# | 4.7 Overfitting | `reports/figures/curves_*.png` (train vs val gap) |
# | 5.1 Explainability | `reports/figures/gradcam_*.png` |
# | 5.3 / 5.4 Fairness + ethics | `ETHICS_AND_FAIRNESS.md` (in repo root) |
# | 6.3 Reproducibility | Fixed seed + `config_*.json` per run |
#
# ### What to write in the report
#
# * **Introduction** — why image classification matters; copy the success criteria from cell 1 of this notebook.
# * **Dataset** — paste the class-distribution table and the sample grid.
# * **Preprocessing** — mention the cleanup pass (EXIF stripped, broken files removed), resize to 32×32, and in-model `Rescaling`. Note that augmentation runs at training time only.
# * **Models** — describe both architectures (parameter counts printed in the model section).
# * **Experiments** — paste `summary_all.csv` and the curves PNGs.
# * **Error analysis** — paste the confusion matrices and `misclassified_*.png` images.
# * **Explainability** — one sentence per Grad-CAM image (“the model focused on the sky instead of the bird”).
# * **Ethics** — already drafted in `ETHICS_AND_FAIRNESS.md`.
# * **Conclusion** — the best-performing run + what you would do next.
#
# ### What to do if a result looks wrong
#
# * **Validation loss bounces around / loss is `nan`** — mixed precision + CPU sometimes misbehaves. Set `USE_MIXED_PRECISION = False` and re-run.
# * **Out of GPU memory** — lower `BATCH_SIZE` from 64 to 32 (or 16).
# * **Training takes forever on CPU** — set `QUICK_MODE = True` in the configuration cell and re-run; results will be worse but the pipeline finishes in a few minutes so you can iterate.
